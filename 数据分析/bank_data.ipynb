# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
train = pd.read_excel(r"C:\Users\59972\Desktop\data\train.xlsx")
test = pd.read_excel(r"C:\Users\59972\Desktop\data\test.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7388/1775827110.py in <module>
# ----> 1 train = pd.read_excel(r"C:\Users\59972\Desktop\data\train.xlsx")
#       2 test = pd.read_excel(r"C:\Users\59972\Desktop\data\test.xlsx")
#
# F:\Program Files (x86)\anacoda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
train.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7388/296699776.py in <module>
# ----> 1 train.info()
#
# NameError: name 'train' is not defined

# %%
train_statistics = train["installment"].describe()
train_statistics
# Out:
# count     999.000000
# mean      434.644865
# std       260.701761
# min        32.950000
# 25%       244.250000
# 50%       372.210000
# 75%       574.405000
# max      1486.550000
# Name: installment, dtype: float64

# %%
train["id"].nunique()
# Out:
# 999

# %%
train.head()
# Out:
#    Unnamed: 0  id  loanAmnt  term  interestRate  installment grade subGrade  \
# 0           0   0     35000     5         19.52       917.97     E       E2
# 1           1   1     18000     5         18.49       461.90     D       D2
# 2           2   2     12000     5         16.99       298.17     D       D3
# 3           3   3     11000     3          7.26       340.96     A       A4
# 4           4   4      3000     3         12.99       101.07     C       C2
#
#    employmentTitle employmentLength  ...    n6    n7    n8   n9   n10  n11  \
# 0              320          2 years  ...   8.0   4.0  12.0  2.0   7.0  0.0
# 1           219843          5 years  ...   NaN   NaN   NaN  NaN  13.0  NaN
# 2            31698          8 years  ...  21.0   4.0   5.0  3.0  11.0  0.0
# 3            46854        10+ years  ...   4.0   7.0  21.0  6.0   9.0  0.0
# 4               54              NaN  ...   9.0  10.0  15.0  7.0  12.0  0.0
#
#    n12  n13  n14  isDefault
# 0  0.0  0.0  2.0          1
# ...

# %%
sns.set()
sns.histplot(train["installment"],kde=True)
# Out:
# <AxesSubplot:xlabel='installment', ylabel='Count'>

# %%
x = train_statistics.loc["mean"]+3*train_statistics.loc["std"]

# %%
(train["installment"]>x).sum()
# Out:
# 11

# %%
train.isnull().sum()
# Out:
# Unnamed: 0              0
# id                      0
# loanAmnt                0
# term                    0
# interestRate            0
# installment             0
# grade                   0
# subGrade                0
# employmentTitle         0
# employmentLength       58
# homeOwnership           0
# annualIncome            0
# verificationStatus      0
# issueDate               0
# purpose                 0
# postCode                0
# regionCode              0
# dti                     0
# delinquency_2years      0
# ficoRangeLow            0
# ficoRangeHigh           0
# openAcc                 0
# pubRec                719
# pubRecBankruptcies      1
# revolBal                0
# revolUtil               0
# totalAcc                0
# initialListStatus       0
# applicationType         0
# earliesCreditLine       0
# title                   0
# policyCode              0
# n0                    276
# n1                     45
# n2                     45
# ...

# %%
test.describe()
# Out:
#        Unnamed: 0             id      loanAmnt        term  interestRate  \
# count  199.000000     199.000000    199.000000  199.000000    199.000000
# mean    99.000000  800099.000000  15189.949749    3.422111     12.775327
# std     57.590508      57.590508   8769.241801    0.818173      4.865754
# min      0.000000  800000.000000   1000.000000    3.000000      5.320000
# 25%     49.500000  800049.500000   8000.000000    3.000000      9.165000
# 50%     99.000000  800099.000000  14400.000000    3.000000     12.120000
# 75%    148.500000  800148.500000  20000.000000    3.000000     15.310000
# max    198.000000  800198.000000  40000.000000    5.000000     30.990000
#
#        installment  employmentTitle  homeOwnership   annualIncome  \
# count   199.000000       199.000000     199.000000     199.000000
# mean    465.590653     64244.643216       0.572864   76145.663317
# std     267.573385    103319.977421       0.638391   46017.125792
# ...

# %% [markdown]
# # 数据建模

# %%
import gc
import time
import numpy as np
import pandas as pd
from datetime import datetime

# %%
#建立字典
d1 = {
    'card_id':np.arange(0,5,1),
    'A':np.random.randn(5)
}
#字典转化为Dataa
t1 = pd.DataFrame(d1)
t1
# Out:
#    card_id         A
# 0        0  0.997197
# 1        1  1.720044
# 2        2 -0.373867
# 3        3  1.521748
# 4        4 -0.338547
