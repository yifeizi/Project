# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import scipy

# %%
data = pd.read_excel("H:\shiyan\data（variables name)\WAGE2.xls")

# %%
data.tail(30)
# Out:
#                                                   wage  hours   IQ  KWW  educ  \
# 933                                                873     44  109   25    12
# 934                                               1000     40  107   32    12
# 935                                               wage  hours   IQ  KWW  educ
# 936                                                NaN    NaN  NaN  NaN   NaN
# 937                                                NaN    NaN  NaN  NaN   NaN
# 938                                          WAGE2.DES    NaN  NaN  NaN   NaN
# 939                                                NaN    NaN  NaN  NaN   NaN
# 940  wage      hours     IQ        KWW       educ  ...    NaN  NaN  NaN   NaN
# 941  married   black     south     urban     sibs  ...    NaN  NaN  NaN   NaN
# 942                                         lwage         NaN  NaN  NaN   NaN
# 943                                                NaN    NaN  NaN  NaN   NaN
# ...

# %%
wage = data['wage'].iloc[0:935]

wage
# Out:
# 0       769
# 1       808
# 2       825
# 3       650
# 4       562
#        ...
# 930     520
# 931    1202
# 932     538
# 933     873
# 934    1000
# Name: wage, Length: 935, dtype: object

# %%
wage.astype(int)
# Out:
# 0       769
# 1       808
# 2       825
# 3       650
# 4       562
#        ...
# 930     520
# 931    1202
# 932     538
# 933     873
# 934    1000
# Name: wage, Length: 935, dtype: int32

# %%
educ = data['educ'][0:935]
educ

educ.astype(int)
# Out:
# 0      12
# 1      18
# 2      14
# 3      12
# 4      11
#        ..
# 930    16
# 931    13
# 932    12
# 933    12
# 934    12
# Name: educ, Length: 935, dtype: int32

# %%
plt.scatter(educ,wage)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 963 entries, 0 to 962
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   wage        958 non-null    object
#  1   hours       936 non-null    object
#  2   IQ          936 non-null    object
#  3   KWW         936 non-null    object
#  4   educ        936 non-null    object
#  5    exper      936 non-null    object
#  6   tenure      936 non-null    object
#  7   age         936 non-null    object
#  8   married     937 non-null    object
#  9   black       936 non-null    object
#  10   south      936 non-null    object
#  11  urban       936 non-null    object
#  12  sibs        936 non-null    object
#  13  brthord     936 non-null    object
#  14  meduc       936 non-null    object
#  15  feduc       936 non-null    object
#  16  lwage       936 non-null    object
# dtypes: object(17)
# memory usage: 128.0+ KB

# %%
df = pd.read_excel("H:\shiyan\data（variables name)\Wage2_1.xls")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 935 entries, 0 to 934
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   wage        935 non-null    int64
#  1   hours       935 non-null    int64
#  2   IQ          935 non-null    int64
#  3   KWW         935 non-null    int64
#  4   educ        935 non-null    int64
#  5    exper      935 non-null    int64
#  6   tenure      935 non-null    int64
#  7   age         935 non-null    int64
#  8   married     935 non-null    int64
#  9   black       935 non-null    int64
#  10   south      935 non-null    int64
#  11  urban       935 non-null    int64
#  12  sibs        935 non-null    int64
#  13  brthord     935 non-null    object
#  14  meduc       935 non-null    object
#  15  feduc       935 non-null    object
#  16  lwage       935 non-null    float64
# dtypes: float64(1), int64(13), object(3)
# memory usage: 124.3+ KB

# %%
c = ['brthord','meduc','feduc']
df=df.drop(c,axis="columns")

# %%
df.head()
# Out:
#    wage  hours   IQ  KWW  educ   exper  tenure  age  married  black   south  \
# 0   769     40   93   35    12      11       2   31        1      0       0
# 1   808     50  119   41    18      11      16   37        1      0       0
# 2   825     40  108   46    14      11       9   33        1      0       0
# 3   650     40   96   32    12      13       7   32        1      0       0
# 4   562     40   74   27    11      14       5   34        1      0       0
#
#    urban  sibs  lwage
# 0      1     1    6.645091
# 1      1     1    6.694562
# 2      1     1    6.715384
# 3      1     4    6.476973
# 4      1    10    6.331502

# %%
i=0
plt.figure()

ax,fig = plt.subplots(2,6,figsize=(18,8))
for col in df.columns:
    i += 1
    plt.subplot(2,7,i)
    sns.scatterplot(data=df,x=col,y="wage")

# %%
#s = sns.load_dataset("df")
sns.pairplot(df)

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.api as sm

# %%
model = sm.OLS(df['wage'],df['educ'])

# %%
result = model.fit()

# %%
print(result.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                   wage   R-squared (uncentered):                   0.865
# Model:                            OLS   Adj. R-squared (uncentered):              0.864
# Method:                 Least Squares   F-statistic:                              5962.
# Date:                Sat, 09 Apr 2022   Prob (F-statistic):                        0.00
# Time:                        21:52:19   Log-Likelihood:                         -6887.2
# No. Observations:                 935   AIC:                                  1.378e+04
# Df Residuals:                     934   BIC:                                  1.378e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
