# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_excel(r"E:\数据\data\bank\train.xlsx")
test = pd.read_excel(r"E:\数据\data\bank\test.xlsx")

# %%
train.describe()
# Out:
#        Unnamed: 0          id      loanAmnt        term  interestRate  \
# count  999.000000  999.000000    999.000000  999.000000    999.000000
# mean   499.000000  499.000000  14376.426426    3.498498     13.198138
# std    288.530761  288.530761   8777.614233    0.865590      4.949507
# min      0.000000    0.000000   1000.000000    3.000000      5.320000
# 25%    249.500000  249.500000   7775.000000    3.000000      9.690000
# 50%    499.000000  499.000000  12000.000000    3.000000     12.620000
# 75%    748.500000  748.500000  20000.000000    3.000000     15.690000
# max    998.000000  998.000000  40000.000000    5.000000     30.940000
#
#        installment  employmentTitle  homeOwnership   annualIncome  \
# count   999.000000       999.000000     999.000000     999.000000
# mean    434.644865     78004.449449       0.650651   75453.657898
# std     260.701761    108713.279881       0.695734   47176.895393
# min      32.950000         1.000000       0.000000   12000.000000
# ...

# %%
train.head()
# Out:
#    Unnamed: 0  id  loanAmnt  term  interestRate  installment grade subGrade  \
# 0           0   0     35000     5         19.52       917.97     E       E2
# 1           1   1     18000     5         18.49       461.90     D       D2
# 2           2   2     12000     5         16.99       298.17     D       D3
# 3           3   3     11000     3          7.26       340.96     A       A4
# 4           4   4      3000     3         12.99       101.07     C       C2
#
#    employmentTitle employmentLength  ...    n6    n7    n8   n9   n10  n11  \
# 0              320          2 years  ...   8.0   4.0  12.0  2.0   7.0  0.0
# 1           219843          5 years  ...   NaN   NaN   NaN  NaN  13.0  NaN
# 2            31698          8 years  ...  21.0   4.0   5.0  3.0  11.0  0.0
# 3            46854        10+ years  ...   4.0   7.0  21.0  6.0   9.0  0.0
# 4               54              NaN  ...   9.0  10.0  15.0  7.0  12.0  0.0
#
#    n12  n13  n14  isDefault
# 0  0.0  0.0  2.0          1
# ...

# %%
train.isnull().sum()
# Out:
# Unnamed: 0              0
# id                      0
# loanAmnt                0
# term                    0
# interestRate            0
# installment             0
# grade                   0
# subGrade                0
# employmentTitle         0
# employmentLength       58
# homeOwnership           0
# annualIncome            0
# verificationStatus      0
# issueDate               0
# purpose                 0
# postCode                0
# regionCode              0
# dti                     0
# delinquency_2years      0
# ficoRangeLow            0
# ficoRangeHigh           0
# openAcc                 0
# pubRec                719
# pubRecBankruptcies      1
# revolBal                0
# revolUtil               0
# totalAcc                0
# initialListStatus       0
# applicationType         0
# earliesCreditLine       0
# title                   0
# policyCode              0
# n0                    276
# n1                     45
# n2                     45
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 48 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          999 non-null    int64
#  1   id                  999 non-null    int64
#  2   loanAmnt            999 non-null    int64
#  3   term                999 non-null    int64
#  4   interestRate        999 non-null    float64
#  5   installment         999 non-null    float64
#  6   grade               999 non-null    object
#  7   subGrade            999 non-null    object
#  8   employmentTitle     999 non-null    int64
#  9   employmentLength    941 non-null    object
#  10  homeOwnership       999 non-null    int64
#  11  annualIncome        999 non-null    float64
#  12  verificationStatus  999 non-null    int64
#  13  issueDate           999 non-null    object
#  14  purpose             999 non-null    int64
# ...

# %%
numerial_tr = ["loanAmnt","interestRate","installment","annualIncome","dti","delinquency_2years","openAcc","totalAcc","revolUtil"]
category_tr = [""]

# %%
for tr in numerial_tr:
    
    print(tr)
    sns.set()
    sns.histplot(train[tr],kde=True).plot()
    next
# Out:
# loanAmnt
# interestRate
# installment
# annualIncome
# dti
# delinquency_2years
# openAcc
# totalAcc
# revolUtil

# %%
sns.set()
sns.histplot(train["isDefault"],kde=True).plot()
# Out:
# []

# %%
statistics = train["installment"].describe()
statistics
# Out:
# count     999.000000
# mean      434.644865
# std       260.701761
# min        32.950000
# 25%       244.250000
# 50%       372.210000
# 75%       574.405000
# max      1486.550000
# Name: installment, dtype: float64

# %%
low = statistics["mean"]-3*statistics["std"]
sup = statistics["mean"]+3*statistics["std"]
low
sup
# Out:
# 1216.7501465609582

# %%
(train["installment"]>sup).sum()
# Out:
# 11

# %%
perticular = train["installment"]>sup
train["perticular"] = perticular
train.head(2)
# Out:
#    Unnamed: 0  id  loanAmnt  term  interestRate  installment grade subGrade  \
# 0           0   0     35000     5         19.52       917.97     E       E2
# 1           1   1     18000     5         18.49       461.90     D       D2
#
#    employmentTitle employmentLength  ...   n7    n8   n9   n10  n11  n12  n13  \
# 0              320          2 years  ...  4.0  12.0  2.0   7.0  0.0  0.0  0.0
# 1           219843          5 years  ...  NaN   NaN  NaN  13.0  NaN  NaN  NaN
#
#    n14  isDefault  perticular
# 0  2.0          1       False
# 1  NaN          0       False
#
# [2 rows x 49 columns]

# %%
train = train.drop(train["perticular"]=="True")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4484/1860070367.py in <module>
# ----> 1 train = train.drop(train["perticular"]=="True")
#
# F:\Program Files (x86)\anacoda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# F:\Program Files (x86)\anacoda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
sns.set()
sns.histplot(train["installment"],kde=True).plot()
# Out:
# []

# %%
train.head()
# Out:
#    Unnamed: 0  id  loanAmnt  term  interestRate  installment grade subGrade  \
# 0           0   0     35000     5         19.52       917.97     E       E2
# 1           1   1     18000     5         18.49       461.90     D       D2
# 2           2   2     12000     5         16.99       298.17     D       D3
# 3           3   3     11000     3          7.26       340.96     A       A4
# 4           4   4      3000     3         12.99       101.07     C       C2
#
#    employmentTitle employmentLength  ...    n7    n8   n9   n10  n11  n12  \
# 0              320          2 years  ...   4.0  12.0  2.0   7.0  0.0  0.0
# 1           219843          5 years  ...   NaN   NaN  NaN  13.0  NaN  NaN
# 2            31698          8 years  ...   4.0   5.0  3.0  11.0  0.0  0.0
# 3            46854        10+ years  ...   7.0  21.0  6.0   9.0  0.0  0.0
# 4               54              NaN  ...  10.0  15.0  7.0  12.0  0.0  0.0
#
#    n13  n14  isDefault  perticular
# ...

# %%
train = train.drop("pubRec",axis=1)

# %%
colunmns = train.columns

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 48 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          999 non-null    int64
#  1   id                  999 non-null    int64
#  2   loanAmnt            999 non-null    int64
#  3   term                999 non-null    int64
#  4   interestRate        999 non-null    float64
#  5   installment         999 non-null    float64
#  6   grade               999 non-null    object
#  7   subGrade            999 non-null    object
#  8   employmentTitle     999 non-null    int64
#  9   employmentLength    941 non-null    object
#  10  homeOwnership       999 non-null    int64
#  11  annualIncome        999 non-null    float64
#  12  verificationStatus  999 non-null    int64
#  13  issueDate           999 non-null    object
#  14  purpose             999 non-null    int64
# ...

# %%
for colunmn in colunmns:
    list_un = train[colunmn].unique()
    print(colunmn)
    print(len(list_un))
    #print(list_un)

#train["grade"].unique()
# Out:
# Unnamed: 0
# 999
# id
# 999
# loanAmnt
# 244
# term
# 2
# interestRate
# 244
# installment
# 916
# grade
# 7
# subGrade
# 34
# employmentTitle
# 791
# employmentLength
# 12
# homeOwnership
# 4
# annualIncome
# 313
# verificationStatus
# 3
# issueDate
# 101
# purpose
# 12
# postCode
# 430
# regionCode
# 46
# dti
# 849
# delinquency_2years
# 10
# ficoRangeLow
# 36
# ficoRangeHigh
# 36
# openAcc
# 38
# pubRecBankruptcies
# 5
# revolBal
# 986
# revolUtil
# 612
# totalAcc
# 68
# initialListStatus
# 2
# applicationType
# 2
# earliesCreditLine
# 330
# title
# 149
# policyCode
# 1
# n0
# 11
# n1
# 17
# n2
# 23
# n3
# 23
# n4
# 21
# n5
# 30
# n6
# 50
# n7
# 29
# n8
# 46
# n9
# 23
# n10
# 39
# n11
# 3
# n12
# 3
# n13
# 9
# n14
# 13
# isDefault
# 2
# perticular
# 2

# %%
train.columns
# Out:
# Index(['Unnamed: 0', 'id', 'loanAmnt', 'term', 'interestRate', 'installment',
#        'grade', 'subGrade', 'employmentTitle', 'employmentLength',
#        'homeOwnership', 'annualIncome', 'verificationStatus', 'issueDate',
#        'purpose', 'postCode', 'regionCode', 'dti', 'delinquency_2years',
#        'ficoRangeLow', 'ficoRangeHigh', 'openAcc', 'pubRecBankruptcies',
#        'revolBal', 'revolUtil', 'totalAcc', 'initialListStatus',
#        'applicationType', 'earliesCreditLine', 'title', 'policyCode', 'n0',
#        'n1', 'n2', 'n3', 'n4', 'n5', 'n6', 'n7', 'n8', 'n9', 'n10', 'n11',
#        'n12', 'n13', 'n14', 'isDefault', 'perticular'],
#       dtype='object')

# %%
train["n9"].unique()
# Out:
# array([ 2., nan,  3.,  6.,  7.,  4., 11.,  5., 13.,  8.,  9., 21., 12.,
#         1., 10.,  0., 14., 30., 16., 15., 17., 22., 18.])

# %%
train.shape[0]
# Out:
# 999
