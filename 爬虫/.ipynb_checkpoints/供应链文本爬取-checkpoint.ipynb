# %%
import requests
import urllib
import re
from bs4 import BeautifulSoup
import numpy as np

# %%
url = "https://www.huawei.com/cn/psirt/security-notices/huawei-sn-20190702-01-finitestate-cn"

# %%
header = {
    "User-Agent": "Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Mobile Safari/537.36 Edg/99.0.1150.36"
}

# %%
resp = requests.get(url,headers=header)

# %%
resp.text
# Out:
# '\r\n\r\n\r\n<!DOCTYPE html>\r\n<html lang="zh">\r\n<head id="Head1"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta charset="utf-8"><meta name="viewport" content="width=device-width,initial-scale=1">\r\n<meta name="description" content="">\r\n<meta name="keywords" content="">\r\n\r\n<!--share begin -->\r\n<meta property="og:title" content="华为PSIRT：《Finite State供应链评估》的技术分析报告">\r\n<meta property="og:description" content="">\r\n<meta property="og:image" content="https://www-file.huawei.com/-/media/corp/home/image/logo_400x200.png">\r\n<meta property="og:url" content="https://www.huawei.com/cn/psirt/security-notices/huawei-sn-20190702-01-finitestate-cn">\r\n<meta property="og:site_name" content="huawei">\r\n<!--share end -->\r\n<!-- add twitter meta begin -->\r\n<meta name="twitter:card" content="summary">\r\n<meta name="twitter:title" content="华为PSIRT：《Finite State供应链评估》的技术分析报告">\r\n<meta name="twitter:description" content="">\r\n<meta name="twitter:image" content="https://w
# ...

# %%
url_list = []
