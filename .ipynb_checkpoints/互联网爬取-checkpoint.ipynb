# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen("http://en.wikipedia.org"+pageUrl)
    bsObj = BeautifulSoup(html)
    try:
        print(bsObj.h1.get_text())
        print(bsObj.find(id="mw-content-text").findAll("p")[0])
        print(bsObj.find(id="ca-edit").find("span").find("a").attrs['href'])
    except AttributeError:
        print("页面缺少一些属性！不过不用担心！")
    for link in bsObj.findAll("a", href=re.compile("^(/wiki/)")):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
# 我们遇到了新页面
                newPage = link.attrs['href']
                print("----------------\n"+newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks("")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# c:\users\59972\appdata\local\programs\python\python39\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# c:\users\59972\appdata\local\programs\python\python39\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1252         """Send a complete request to the server."""
# -> 1253         self._send_request(method, url, body, headers, encode_chunked)
#    1254
#
# c:\users\59972\appdata\local\programs\python\python39\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1298             body = _encode(body, 'body')
# -> 1299         self.endheaders(body, encode_chunked=encode_chunked)
#    1300
#
# c:\users\59972\appdata\local\programs\python\python39\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1247             raise CannotSendHeader()
# -> 1248         self._send_output(message_body, encode_chunked=encode_chunked)
#    1249
#
# c:\users\59972\appdata\local\programs\python\python39\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1007         del self._buffer[:]
# -> 1008         self.send(msg)
#    1009
#
# c:\users\59972\appdata\local\programs\python\python39\lib\http\client.py in send(self, data)
#     947             if self.auto_open:
# --> 948                 self.connect()
#     949             else:
#
# c:\users\59972\appdata\local\programs\python\python39\lib\http\client.py in connect(self)
#     918         """Connect to the host and port specified in __init__."""
# --> 919         self.sock = self._create_connection(
#     920             (self.host,self.port), self.timeout, self.source_address)
#
# c:\users\59972\appdata\local\programs\python\python39\lib\socket.py in create_connection(address, timeout, source_address)
#     842         try:
# --> 843             raise err
#     844         finally:
#
# c:\users\59972\appdata\local\programs\python\python39\lib\socket.py in create_connection(address, timeout, source_address)
#     830                 sock.bind(source_address)
# --> 831             sock.connect(sa)
#     832             # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1844/1570422369.py in <module>
#      21                 pages.add(newPage)
#      22                 getLinks(newPage)
# ---> 23 getLinks("")
#
# ~\AppData\Local\Temp/ipykernel_1844/1570422369.py in getLinks(pageUrl)
#       5 def getLinks(pageUrl):
#       6     global pages
# ----> 7     html = urlopen("http://en.wikipedia.org"+pageUrl)
#       8     bsObj = BeautifulSoup(html)
#       9     try:
#
# c:\users\59972\appdata\local\programs\python\python39\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# c:\users\59972\appdata\local\programs\python\python39\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     515
#     516         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517         response = self._open(req, data)
#     518
#     519         # post-process response
#
# c:\users\59972\appdata\local\programs\python\python39\lib\urllib\request.py in _open(self, req, data)
#     532
#     533         protocol = req.type
# --> 534         result = self._call_chain(self.handle_open, protocol, protocol +
#     535                                   '_open', req)
#     536         if result:
#
# c:\users\59972\appdata\local\programs\python\python39\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# c:\users\59972\appdata\local\programs\python\python39\lib\urllib\request.py in http_open(self, req)
#    1373
#    1374     def http_open(self, req):
# -> 1375         return self.do_open(http.client.HTTPConnection, req)
#    1376
#    1377     http_request = AbstractHTTPHandler.do_request_
#
# c:\users\59972\appdata\local\programs\python\python39\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#    1348             except OSError as err: # timeout error
# -> 1349                 raise URLError(err)
#    1350             r = h.getresponse()
#    1351         except:
#
# URLError: <urlopen error [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import datetime
import random
pages = set()
random.seed(datetime.datetime.now())
# 获取页面所有内链的列表
def getInternalLinks(bsObj, includeUrl):
    internalLinks = []
# 找出所有以"/"开头的链接
    for link in bsObj.findAll("a", href=re.compile("^(/|.*"+includeUrl+")")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in internalLinks:
                internalLinks.append(link.attrs['href'])
    return internalLinks
# 获取页面所有外链的列表
def getExternalLinks(bsObj, excludeUrl):
    externalLinks = []
# 找出所有以"http"或"www"开头且不包含当前URL的链接
    for link in bsObj.findAll("a",href=re.compile("^(http|www)((?!"+excludeUrl+").)*$")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in externalLinks:
                externalLinks.append(link.attrs['href'])
    return externalLinks
def splitAddress(address):
    addressParts = address.replace("http://", "").split("/")
    return addressParts
def getRandomExternalLink(startingPage):
    html = urlopen(startingPage)
    bsObj = BeautifulSoup(html)
    externalLinks = getExternalLinks(bsObj, splitAddress(startingPage)[0])
    if len(externalLinks) == 0:
        internalLinks = getInternalLinks(startingPage)
        return getNextExternalLink(internalLinks[random.randint(0,len(internalLinks)-1)])
    else:
        return externalLinks[random.randint(0, len(externalLinks)-1)]
def followExternalOnly(startingSite):
    externalLink = getRandomExternalL
# 随机外链是：http://tieba.baidu.com
# 随机外链是：https://top.baidu.com/board?platform=pc&sa=pcindex_entry
# 随机外链是：http://www.beian.gov.cn/portal/registerSystemInfo?recordcode=11000002000001
# 随机外链是：http://image.baidu.com
# 随机外链是：http://xueshu.baidu.com
# 随机外链是：https://live.baidu.com/
# 随机外链是：http://image.baidu.com/i?tn=baiduimage&ps=1&ct=201326592&lm=-1&cl=2&nc=1&ie=utf-8
# 随机外链是：http://news.baidu.com
# 随机外链是：http://news.baidu.com
# 随机外链是：https://top.baidu.com/board?platform=pc&sa=pcindex_entry
# 随机外链是：http://tieba.baidu.com/f?fr=wwwt
# 随机外链是：http://www.beian.gov.cn/portal/registerSystemInfo?recordcode=11000002000001
# 随机外链是：http://map.baidu.com
# 随机外链是：https://haokan.baidu.com/?sfrom=baidu-top
# 随机外链是：http://image.baidu.com/i?tn=baiduimage&ps=1&ct=201326592&lm=-1&cl=2&nc=1&ie=utf-8
# 随机外链是：https://top.baidu.com/board?platform=pc&sa=pcindex_entry
# 随机外链是：https://top.baidu.com/board?platform=pc&sa=pcindex_entry
# 随机外链是：http://image.baidu.com
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in <module>
#      41     followExternalOnly(externalLink)
#      42
# ---> 43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
# ---> 41     followExternalOnly(externalLink)
#      42
#      43 followExternalOnly("http://www.baidu.com")
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in followExternalOnly(startingSite)
#      37         return externalLinks[random.randint(0, len(externalLinks)-1)]
#      38 def followExternalOnly(startingSite):
# ---> 39     externalLink = getRandomExternalLink("http://www.baidu.com")
#      40     print("随机外链是："+externalLink)
#      41     followExternalOnly(externalLink)
#
# ~\AppData\Local\Temp/ipykernel_1844/276628673.py in getRandomExternalLink(startingPage)
#      29 def getRandomExternalLink(startingPage):
#      30     html = urlopen(startingPage)
# ---> 31     bsObj = BeautifulSoup(html)
#      32     externalLinks = getExternalLinks(bsObj, splitAddress(startingPage)[0])
#      33     if len(externalLinks) == 0:
#
# c:\users\59972\appdata\local\programs\python\python39\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     309
#     310         if hasattr(markup, 'read'):        # It's a file-type object.
# --> 311             markup = markup.read()
#     312         elif len(markup) <= 256 and (
#     313                 (isinstance(markup, bytes) and not b'<' in markup)
#
# c:\users\59972\appdata\local\programs\python\python39\lib\http\client.py in read(self, amt)
#     460
#     461             if self.chunked:
# --> 462                 return self._readall_chunked()
#     463
#     464             if self.length is None:
#
# c:\users\59972\appdata\local\programs\python\python39\lib\http\client.py in _readall_chunked(self)
#     570                 if chunk_left is None:
#     571                     break
# --> 572                 value.append(self._safe_read(chunk_left))
#     573                 self.chunk_left = 0
#     574             return b''.join(value)
#
# c:\users\59972\appdata\local\programs\python\python39\lib\http\client.py in _safe_read(self, amt)
#     607         IncompleteRead exception can be used to detect the problem.
#     608         """
# --> 609         data = self.fp.read(amt)
#     610         if len(data) < amt:
#     611             raise IncompleteRead(data, amt-len(data))
#
# c:\users\59972\appdata\local\programs\python\python39\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# # 使用urllib库时两种添加请求头的方法
#
#
# 第一种方法：
# link = 'https://movie.douban.com/top250'
#
# #	在这里，必须使用元组或列表的方式定制请求头。
# headers = （'user-agent','mozilla/5.0'）
#
# opener = urllib.request.build_opener()
#
# #	请求头会以列表包含元组或列表的方式进行保存。
# opener.addheaders = [headers]
# r = opener.open(link,timeout=10)
#
# #	打印请求状态码，这里返回200，表示请求成功。
# print(r.code)
#
#
# 第二种方法：
# link = 'https://movie.douban.com/top250'
# headers = {'user-agent':'mozilla/5.0'}
#
# '''
# 使用Request类添加请求头可以不使用headers这个参数。而使用这个类的实例化对象的方法
# add_header(key='user-agent',val='mozilla/5.0')
# '''
#
# add = urllib.request.Request(url=link,headers=headers)
#
# r = urllib.request.urlopen(url=add,timeout=10)
# print(r.code)

# %%
import urllib.request
import requests
from bs4 import BeautifulSoup 


allExtLinks = set()
allIntLinks = set()
def getAllExternalLinks(siteUrl):
    header = {"User-Agent": "Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Mobile Safari/537.36 Edg/94.0.992.38"}
    opener = urllib.request.build_opener()
    opener.addheaders = [header]
    
    html = requests.get(siteUrl,headers=header)
    
    #html = urlopen(siteUrl)
    #html = opener.open(siteUrl,timeout=10)
    
    
    bsObj = BeautifulSoup(html.text,"html.parser")#这里要指定HTML解析器
    internalLinks = getInternalLinks(bsObj,splitAddress(siteUrl)[0])
    externalLinks = getExternalLinks(bsObj,splitAddress(siteUrl)[0])
    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.add(link)
            print(link)
    for link in internalLinks:
        if link not in allIntLinks:
            print("即将获取链接的URL是："+link)
            allIntLinks.add(link)
            getAllExternalLinks(link)
getAllExternalLinks("https://book.douban.com/top250")
# Out:
# https://accounts.douban.com/passport/login?source=book
# https://www.douban.com/doubanapp/app?channel=top-nav
# https://www.douban.com/doubanapp/app?channel=qipao
# https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=iOS
# https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=Android
# https://www.douban.com
# https://book.douban.com
# https://movie.douban.com
# https://music.douban.com
# https://www.douban.com/location
# https://www.douban.com/group
# https://read.douban.com/?dcs=top-nav&dcm=douban
# https://douban.fm/?from_=shire_top_nav
# https://time.douban.com/?dt_time_source=douban-web_top_nav
# https://market.douban.com/?utm_campaign=douban_top_nav&utm_source=douban&utm_medium=pc_web
# https://book.douban.com/cart/
# https://read.douban.com/ebooks/?dcs=book-nav&dcm=douban
# https://market.douban.com/book?utm_campaign=book_nav_freyr&utm_source=douban&utm_medium=pc_web
# https://book.douban.com/annual/2020?source=navigation
# https://www.douban.com/standbyme/2020?fullscreen=true&hidenav=true&autorotate=false&source=book_navigation
# https://market.douban.com/cart/?biz_type=book&utm_campaign=book_nav_cart&utm_source=douban&utm_medium=pc_web
# https://book.douban.com/annual/2020?source=book_navigation
# https://book.douban.com/subject/1007305/
# https://book.douban.com/subject/4913064/
# https://book.douban.com/subject/6082808/
# https://book.douban.com/subject/4820710/
# https://book.douban.com/subject/1068920/
# https://book.douban.com/subject/6518605/
# https://book.douban.com/subject/1019568/
# https://book.douban.com/subject/3259440/
# https://book.douban.com/subject/1084336/
# https://book.douban.com/subject/1040211/
# https://book.douban.com/subject/27614904/
# https://book.douban.com/subject/2035179/
# https://book.douban.com/subject/1060068/
# https://book.douban.com/subject/1255625/
# https://book.douban.com/subject/1046209/
# https://book.douban.com/subject/1200840/
# https://book.douban.com/subject/1008145/
# https://book.douban.com/subject/10594787/
# https://book.douban.com/subject/4908885/
# https://book.douban.com/subject/3674537/
# https://book.douban.com/subject/1054685/
# https://book.douban.com/subject/1770782/
# https://book.douban.com/subject/25985021/
# https://book.douban.com/subject/24531956/
# https://book.douban.com/subject/1858513/
# https://book.douban.com/top250?start=25
# https://book.douban.com/top250?start=50
# https://book.douban.com/top250?start=75
# https://book.douban.com/top250?start=100
# https://book.douban.com/top250?start=125
# https://book.douban.com/top250?start=150
# https://book.douban.com/top250?start=175
# https://book.douban.com/top250?start=200
# https://book.douban.com/top250?start=225
# https://www.douban.com/hnypt/variformcyst.py
# https://www.douban.com/about
# https://www.douban.com/jobs
# https://www.douban.com/about?topic=contactus
# https://www.douban.com/about/legal
# https://help.douban.com/?app=book
# https://book.douban.com/library_invitation
# https://www.douban.com/doubanapp/
# https://www.douban.com/partner/
# 即将获取链接的URL是：https://accounts.douban.com/passport/login?source=book
# https://accounts.douban.com/passport/agreement
# https://m.douban.com/page/wijmvyh
# https://www.douban.com/accounts/weixin
# https://accounts.douban.com/connect/sina_weibo/?from=None&amp;redir=http://www.douban.com}&amp;fallback=
# 即将获取链接的URL是：https://accounts.douban.com/passport/agreement
# https://www.douban.com/about/agreement
# https://www.douban.com/about/privacy
# https://www.douban.com/about/agreement?page=history
# https://help.douban.com/complaint/
# https://www.douban.com/about/guideline
# https://www.douban.com/about/copyright
# https://www.douban.com/about/privacy?page=history
# https://www.douban.com/about/thirdpartsdk
# https://www.douban.com/about/ad_setting
# 即将获取链接的URL是：https://www.douban.com/about/agreement
# 即将获取链接的URL是：/about/agreement?page=history
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1844/30580498.py in <module>
#      29             allIntLinks.add(link)
#      30             getAllExternalLinks(link)
# ---> 31 getAllExternalLinks("https://book.douban.com/top250")
#
# ~\AppData\Local\Temp/ipykernel_1844/30580498.py in getAllExternalLinks(siteUrl)
#      28             print("即将获取链接的URL是："+link)
#      29             allIntLinks.add(link)
# ---> 30             getAllExternalLinks(link)
#      31 getAllExternalLinks("https://book.douban.com/top250")
#
# ~\AppData\Local\Temp/ipykernel_1844/30580498.py in getAllExternalLinks(siteUrl)
#      28             print("即将获取链接的URL是："+link)
#      29             allIntLinks.add(link)
# ---> 30             getAllExternalLinks(link)
#      31 getAllExternalLinks("https://book.douban.com/top250")
#
# ~\AppData\Local\Temp/ipykernel_1844/30580498.py in getAllExternalLinks(siteUrl)
#      28             print("即将获取链接的URL是："+link)
#      29             allIntLinks.add(link)
# ---> 30             getAllExternalLinks(link)
#      31 getAllExternalLinks("https://book.douban.com/top250")
#
# ~\AppData\Local\Temp/ipykernel_1844/30580498.py in getAllExternalLinks(siteUrl)
#      28             print("即将获取链接的URL是："+link)
#      29             allIntLinks.add(link)
# ---> 30             getAllExternalLinks(link)
#      31 getAllExternalLinks("https://book.douban.com/top250")
#
# ~\AppData\Local\Temp/ipykernel_1844/30580498.py in getAllExternalLinks(siteUrl)
#      11     opener.addheaders = [header]
#      12
# ---> 13     html = requests.get(siteUrl,headers=header)
#      14
#      15     #html = urlopen(siteUrl)
#
# c:\users\59972\appdata\local\programs\python\python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\users\59972\appdata\local\programs\python\python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\users\59972\appdata\local\programs\python\python39\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     526             hooks=hooks,
#     527         )
# --> 528         prep = self.prepare_request(req)
#     529
#     530         proxies = proxies or {}
#
# c:\users\59972\appdata\local\programs\python\python39\lib\site-packages\requests\sessions.py in prepare_request(self, request)
#     454
#     455         p = PreparedRequest()
# --> 456         p.prepare(
#     457             method=request.method.upper(),
#     458             url=request.url,
#
# c:\users\59972\appdata\local\programs\python\python39\lib\site-packages\requests\models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     314
#     315         self.prepare_method(method)
# --> 316         self.prepare_url(url, params)
#     317         self.prepare_headers(headers)
#     318         self.prepare_cookies(cookies)
#
# c:\users\59972\appdata\local\programs\python\python39\lib\site-packages\requests\models.py in prepare_url(self, url, params)
#     388             error = error.format(to_native_string(url, 'utf8'))
#     389
# --> 390             raise MissingSchema(error)
#     391
#     392         if not host:
#
# MissingSchema: Invalid URL '/about/agreement?page=history': No schema supplied. Perhaps you meant http:///about/agreement?page=history?
